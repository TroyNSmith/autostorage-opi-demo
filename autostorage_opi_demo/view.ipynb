# %%
from pathlib import Path

import py3Dmol

path = Path("/home/tns97255/autostorage-opi-demo/out/4_NEB/optts.xyz")

# Initialize the py3Dmol viewer
view = py3Dmol.view(width=600, height=400)

# Add all frames to the viewer
view.addModelsAsFrames(path.read_text().replace(">\n", ""), "xyz")

# Set the visualization style for all models/frames
view.setStyle({}, {"stick": {"radius": 0.15}, "sphere": {"scale": 0.25}})

# Configure background and framing
view.setBackgroundColor("white")
view.zoomTo()

# Start the animation loop ('forward' or 'loop')
view.animate({"loop": "forward"})

view.show()
# Out:
# <div id="3dmolviewer_17898457103777962"  style="position: relative; width: 600px; height: 400px;">
#         <p id="3dmolwarning_17898457103777962" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.5/build/3Dmol-min.js');
# }
#
# var viewer_17898457103777962 = null;
# var warn = document.getElementById("3dmolwarning_17898457103777962");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17898457103777962 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17898457103777962"),{backgroundColor:"white"});
# viewer_17898457103777962.zoomTo();
# 	viewer_17898457103777962.addModelsAsFrames("17\nCoordinates from ORCA-job optts E -268.750132237467\n  C           2.57648343001821      0.38878961570501     -0.56631239519365\n  C           1.33928118170985     -0.43555076203661     -0.22690811861193\n  C           0.06574840048441      0.02419262742934     -0.37321828865204\n  C          -1.14096973682488     -0.78842343022602     -0.07921006215325\n  C          -2.40380286522421     -0.00308154858049      0.33192134915837\n  H           3.17524595033765     -0.10792627150055     -1.32604041284512\n  H           2.29301652820246      1.36748281581138     -0.93640497447083\n  H           3.20397863778462      0.52012311737256      0.31200110878108\n  H           1.50703138678147     -1.43249455114854      0.15570864550011\n  H          -0.09805633195453      1.02005375337894     -0.75892268586079\n  H          -1.50329818431847     -1.38555855965158     -1.19858236559066\n  H          -0.93738577552814     -1.64200824902376      0.55786256441643\n  H          -3.26517879401557     -0.66102091048556      0.38404048435625\n  H          -2.26366337376384      0.45774852739743      1.30577397880979\n  H          -2.61192933236565      0.78070577065137     -0.38855637678404\n  O          -1.70805544841470     -1.98831751262647     -2.23974629202854\n  H          -0.78101867290868     -2.00985043246644     -2.59080915883117\n","xyz");
# 	viewer_17898457103777962.setStyle({},{"stick": {"radius": 0.15}, "sphere": {"scale": 0.25}});
# 	viewer_17898457103777962.setBackgroundColor("white");
# 	viewer_17898457103777962.zoomTo();
# 	viewer_17898457103777962.animate({"loop": "forward"});
# viewer_17898457103777962.render();
# });
# </script>
