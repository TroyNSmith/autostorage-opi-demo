# %%
from pathlib import Path

import py3Dmol

path = Path("/home/tns97255/autostorage-opi-demo/out/3_SCAN/scan/ScanTS.002.xyz")

# Initialize the py3Dmol viewer
view = py3Dmol.view(width=600, height=400)

# Add all frames to the viewer
view.addModelsAsFrames(path.read_text().replace(">\n", ""), "xyz")

# Set the visualization style for all models/frames
view.setStyle({}, {"stick": {"radius": 0.15}, "sphere": {"scale": 0.25}})

# Configure background and framing
view.setBackgroundColor("white")
view.zoomTo()

# Start the animation loop ('forward' or 'loop')
view.animate({"loop": "forward"})

view.show()
# Out:
# <div id="3dmolviewer_17898406906406822"  style="position: relative; width: 600px; height: 400px;">
#         <p id="3dmolwarning_17898406906406822" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.5/build/3Dmol-min.js');
# }
#
# var viewer_17898406906406822 = null;
# var warn = document.getElementById("3dmolwarning_17898406906406822");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17898406906406822 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17898406906406822"),{backgroundColor:"white"});
# viewer_17898406906406822.zoomTo();
# 	viewer_17898406906406822.addModelsAsFrames("17\nCoordinates from ORCA-job ScanTS E -268.751304593882\n  C           2.53591712382147      0.43899409572443     -0.58738156181065\n  C           1.31478175276597     -0.39898680072505     -0.22235854957449\n  C           0.04227286534492     -0.00289922541048     -0.44012684206765\n  C          -1.16099820151391     -0.83730850829624     -0.11009417756912\n  C          -2.39632952229467     -0.02097261800302      0.33637128638539\n  H           3.17531122726368     -0.09375595540013     -1.28697384251949\n  H           2.23383795269629      1.37599400238389     -1.04096791911154\n  H           3.12895791824238      0.65904676067392      0.29695134796697\n  H           1.50657832044622     -1.35637592524654      0.24111251698656\n  H          -0.14698368412030      0.95470333323456     -0.90290207195314\n  H          -1.51527358124378     -1.44280466645771     -1.12006062052219\n  H          -0.91866540638206     -1.62602990479901      0.59327681467243\n  H          -3.25350693336836     -0.67065547962703      0.47779489747732\n  H          -2.19574108351146      0.49314453922384      1.27123854197827\n  H          -2.64818394489016      0.72139525492768     -0.41299469137095\n  O          -1.70832178167321     -1.99924135875397     -2.21125748861931\n  H          -0.80827379523581     -1.85748364828800     -2.61101589423373\n","xyz");
# 	viewer_17898406906406822.setStyle({},{"stick": {"radius": 0.15}, "sphere": {"scale": 0.25}});
# 	viewer_17898406906406822.setBackgroundColor("white");
# 	viewer_17898406906406822.zoomTo();
# 	viewer_17898406906406822.animate({"loop": "forward"});
# viewer_17898406906406822.render();
# });
# </script>
